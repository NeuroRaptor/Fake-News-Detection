# %% [markdown]
# # Fake News Detection Using Natural Language Processing and Machine Learning

# %% [markdown]
# ### Setup and imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re
import string

# %%
fake_news_train = pd.read_csv("liar_dataset/train.tsv", sep="\t")
fake_news_valid= pd.read_csv('liar_dataset/valid.tsv', sep='\t')
fake_news_test = pd.read_csv('liar_dataset/test.tsv', sep='\t')

# %%
fake_news_train.head()
# Out:
#     2635.json        false  \
# 0  10540.json    half-true
# 1    324.json  mostly-true
# 2   1123.json        false
# 3   9028.json    half-true
# 4  12465.json         true
#
#   Says the Annies List political group supports third-trimester abortions on demand.  \
# 0  When did the decline of coal start? It started...
# 1  Hillary Clinton agrees with John McCain "by vo...
# 2  Health care reform legislation is likely to ma...
# 3  The economic turnaround started at the end of ...
# 4  The Chicago Bears have had more starting quart...
#
#                              abortion    dwayne-bohac  \
# 0  energy,history,job-accomplishments  scott-surovell
# 1                      foreign-policy    barack-obama
# 2                         health-care    blog-posting
# 3                        economy,jobs   charlie-crist
# 4                           education       robin-vos
#
#          State representative      Texas  republican     0     1    0.1  \
# 0              State delegate   Virginia    democrat   0.0   0.0    1.0
# 1                   President   Illinois    democrat  70.0  71.0  160.0
# 2                         NaN        NaN        none   7.0  19.0    3.0
# 3                         NaN    Florida    democrat  15.0   9.0   20.0
# 4  Wisconsin Assembly speaker  Wisconsin  republican   0.0   3.0    2.0
#
#      0.2   0.3                   a mailer
# 0    1.0   0.0            a floor speech.
# 1  163.0   9.0                     Denver
# 2    5.0  44.0             a news release
# 3   19.0   2.0        an interview on CNN
# 4    5.0   1.0  a an online opinion-piece

# %%
fake_news_train.tail()
# Out:
#       Statement Id        Label  \
# 10264    5473.json  mostly-true
# 10265    3408.json  mostly-true
# 10266    3959.json    half-true
# 10267    2253.json        FALSE
# 10268    1155.json   pants-fire
#
#                                                Statement  \
# 10264  There are a larger number of shark attacks in ...
# 10265  Democrats have now become the party of the [At...
# 10266  Says an alternative to Social Security that op...
# 10267  On lifting the U.S. Cuban embargo and allowing...
# 10268  The Department of Veterans Affairs has a manua...
#
#                           Subject         Speaker  \
# 10264           animals,elections    aclu-florida
# 10265                   elections     alan-powell
# 10266  retirement,social-security     herman-cain
# 10267      florida,foreign-policy     jeff-greene
# 10268        health-care,veterans  michael-steele
#
#                                        Speaker's Job     State       Party  \
# 10264                                            NaN   Florida        none
# 10265                                            NaN   Georgia  republican
# 10266                                            NaN   Georgia  republican
# 10267                                            NaN   Florida    democrat
# 10268  chairman of the Republican National Committee  Maryland  republican
#
#        Barely True Counts  False Count  Half True Counts  Mostly True Counts  \
# 10264                 0.0          1.0               1.0                 1.0
# 10265                 0.0          0.0               0.0                 1.0
# 10266                 4.0         11.0               5.0                 3.0
# 10267                 3.0          1.0               3.0                 0.0
# 10268                 0.0          1.0               1.0                 0.0
#
#        Pants on Fire Counts                                      Context Venue
# 10264                   0.0                  interview on "The Colbert Report"
# 10265                   0.0                                       an interview
# 10266                   3.0                   a Republican presidential debate
# 10267                   0.0  a televised debate on Miami's WPLG-10 against ...
# 10268                   2.0                               a Fox News interview

# %%
fake_news_train.describe()
# Out:
#        Barely True Counts   False Count  Half True Counts  Mostly True Counts  \
# count        10263.000000  10263.000000      10263.000000        10263.000000
# mean            11.549839     13.304394         17.168762           16.465166
# std             18.992224     24.132578         35.899983           36.202646
# min              0.000000      0.000000          0.000000            0.000000
# 25%              0.000000      0.000000          0.000000            0.000000
# 50%              2.000000      2.000000          3.000000            3.000000
# 75%             12.000000     15.000000         13.000000           11.000000
# max             70.000000    114.000000        160.000000          163.000000
#
#        Pants on Fire Counts
# count          10263.000000
# mean               6.202670
# std               16.121555
# min                0.000000
# 25%                0.000000
# 50%                1.000000
# 75%                5.000000
# max              105.000000

# %%
fake_news_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10239 entries, 0 to 10238
# Data columns (total 14 columns):
#  #   Column                                                                              Non-Null Count  Dtype
# ---  ------                                                                              --------------  -----
#  0   2635.json                                                                           10239 non-null  object
#  1   false                                                                               10239 non-null  object
#  2   Says the Annies List political group supports third-trimester abortions on demand.  10239 non-null  object
#  3   abortion                                                                            10237 non-null  object
#  4   dwayne-bohac                                                                        10237 non-null  object
#  5   State representative                                                                7341 non-null   object
#  6   Texas                                                                               8029 non-null   object
#  7   republican                                                                          10237 non-null  object
#  8   0                                                                                   10237 non-null  float64
#  9   1                                                                                   10237 non-null  float64
#  10  0.1                                                                                 10237 non-null  float64
#  11  0.2                                                                                 10237 non-null  float64
#  12  0.3                                                                                 10237 non-null  float64
#  13  a mailer                                                                            10137 non-null  object
# dtypes: float64(5), object(9)
# memory usage: 1.1+ MB

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# #### Remove duplicates
#
# #### Normalize text: lowercase, punctuation removal

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub(r"http\S+|www\S+|https\S+", '', text, flags=re.MULTILINE)
    text = re.sub(r'\@w+|\#','', text)
    text = re.sub(r'[^\w\s]', '', text)
    return text

fake_news_train['clean_text'] = fake_news_train['text'].apply(clean_text)
fake_news_valid['clean_text'] = fake_news_valid['text'].apply(clean_text)
fake_news_test['clean_text'] = fake_news_test['text'].apply(clean_text)
