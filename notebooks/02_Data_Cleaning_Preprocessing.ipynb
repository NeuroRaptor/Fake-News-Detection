# %% [markdown]
# #   2. Data Cleaning & Preprocessing

# %% [markdown]
# ## Clean the combined dataset

# %% [markdown]
# ## 1. Load Dataset

# %%
import pandas as pd
import numpy as np
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from bs4 import BeautifulSoup
import string

# %%
combined_fake_news_dataset_df = pd.read_csv("../data/interim/combined_fake_news_dataset.csv")

# %%
combined_fake_news_dataset_df.head()
# Out:
#                                                 text  label original_label  \
# 0  (Reuters) - President Donald Trump is set to s...      1              1
# 1  LANY, Czech Republic (Reuters) - Czech electio...      1              1
# 2  Says comprehensive immigration reform will add...      0      half-true
# 3  Inside Nikki Bella's Strong Support System Fol...      1              1
# 4  Ellen DeGeneres makes joke about Jennifer Anis...      0              0
#
#                dataset
# 0                 ISOT
# 1                 ISOT
# 2                 LIAR
# 3  FakeNewsNet_Minimal
# 4  FakeNewsNet_Minimal

# %%
combined_fake_news_dataset_df.tail()
# Out:
#                                                     text  label  \
# 80880  Says Rep. Maxine Waters, D-Calif., only needs ...      0
# 80881  Remember when colleges and university were one...      0
# 80882  Yolanda Hadid Addresses Gigi Hadid Pregnancy R...      0
# 80883  The Governor did not consult members of his ow...      0
# 80884  WASHINGTON (Reuters) - The U.S. Senate will pu...      1
#
#       original_label              dataset
# 80880      half-true                 LIAR
# 80881              0                 ISOT
# 80882              0  FakeNewsNet_Minimal
# 80883          false                 LIAR
# 80884              1                 ISOT

# %%
combined_fake_news_dataset_df.describe()
# Out:
#               label
# count  80885.000000
# mean       0.536132
# std        0.498696
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000

# %%
combined_fake_news_dataset_df.duplicated().sum()
# Out:
# np.int64(7620)

# %%
# missing values

combined_fake_news_dataset_df.isnull().sum()
# Out:
# text              0
# label             0
# original_label    0
# dataset           0
# dtype: int64

# %% [markdown]
# ## 2. Drop Duplicates

# %%
combined_fake_news_dataset_df.drop_duplicates(inplace=True)

# %%
combined_fake_news_dataset_df
# Out:
#                                                     text  label  \
# 0      (Reuters) - President Donald Trump is set to s...      1
# 1      LANY, Czech Republic (Reuters) - Czech electio...      1
# 2      Says comprehensive immigration reform will add...      0
# 3      Inside Nikki Bella's Strong Support System Fol...      1
# 4      Ellen DeGeneres makes joke about Jennifer Anis...      0
# ...                                                  ...    ...
# 80879  Conservatives are, once again, on the losing s...      0
# 80880  Says Rep. Maxine Waters, D-Calif., only needs ...      0
# 80882  Yolanda Hadid Addresses Gigi Hadid Pregnancy R...      0
# 80883  The Governor did not consult members of his ow...      0
# 80884  WASHINGTON (Reuters) - The U.S. Senate will pu...      1
#
#       original_label              dataset
# 0                  1                 ISOT
# 1                  1                 ISOT
# 2          half-true                 LIAR
# 3                  1  FakeNewsNet_Minimal
# 4                  0  FakeNewsNet_Minimal
# ...              ...                  ...
# 80879              0                 ISOT
# 80880      half-true                 LIAR
# 80882              0  FakeNewsNet_Minimal
# 80883          false                 LIAR
# 80884              1                 ISOT
#
# [73265 rows x 4 columns]

# %% [markdown]
# ## 3. Clean Text

# %%
# Clean text
def clean_text(text):
    text = BeautifulSoup(text, "html.parser").get_text()  # Remove HTML
    text = re.sub(r"http\S+|www\S+", "", text)            # Remove URLs
    text = text.lower()                                   # Lowercase
    text = re.sub(r'\[.*?\]', '', text)                   # Remove text in brackets
    text = re.sub(r'\w*\d\w*', '', text)                  # Remove words with numbers
    text = text.translate(str.maketrans('', '', string.punctuation))  # Remove punctuation
    text = re.sub(r'\s+', ' ', text).strip()              # Remove extra whitespace
    return text

# %%
combined_fake_news_dataset_df['clean_text'] =  combined_fake_news_dataset_df['text'].apply(clean_text)
# Out:
# C:\Users\arpit\AppData\Local\Temp\ipykernel_13576\4160528775.py:3: MarkupResemblesLocatorWarning: The input passed in on this line looks more like a URL than HTML or XML.
#
# If you meant to use Beautiful Soup to parse the web page found at a certain URL, then something has gone wrong. You should use an Python package like 'requests' to fetch the content behind the URL. Once you have the content as a string, you can feed that string into Beautiful Soup.
#
# However, if you want to parse some data that happens to look like a URL, then nothing has gone wrong: you are using Beautiful Soup correctly, and this warning is spurious and can be filtered. To make this warning go away, run this code before calling the BeautifulSoup constructor:
#
#     from bs4 import MarkupResemblesLocatorWarning
#     import warnings
#
#     warnings.filterwarnings("ignore", category=MarkupResemblesLocatorWarning)
#
#   text = BeautifulSoup(text, "html.parser").get_text()  # Remove HTML

# %%
combined_fake_news_dataset_df.head()
# Out:
#                                                 text  label original_label  \
# 0  (Reuters) - President Donald Trump is set to s...      1              1
# 1  LANY, Czech Republic (Reuters) - Czech electio...      1              1
# 2  Says comprehensive immigration reform will add...      0      half-true
# 3  Inside Nikki Bella's Strong Support System Fol...      1              1
# 4  Ellen DeGeneres makes joke about Jennifer Anis...      0              0
#
#                dataset                                         clean_text
# 0                 ISOT  reuters president donald trump is set to sign ...
# 1                 ISOT  lany czech republic reuters czech election win...
# 2                 LIAR  says comprehensive immigration reform will add...
# 3  FakeNewsNet_Minimal  inside nikki bellas strong support system foll...
# 4  FakeNewsNet_Minimal  ellen degeneres makes joke about jennifer anis...

# %% [markdown]
# ## 4. Tokenization

# %%
combined_fake_news_dataset_df['tokens'] = combined_fake_news_dataset_df['clean_text'].apply(lambda x: x.split())

# %%
combined_fake_news_dataset_df
# Out:
#                                                     text  label  \
# 0      (Reuters) - President Donald Trump is set to s...      1
# 1      LANY, Czech Republic (Reuters) - Czech electio...      1
# 2      Says comprehensive immigration reform will add...      0
# 3      Inside Nikki Bella's Strong Support System Fol...      1
# 4      Ellen DeGeneres makes joke about Jennifer Anis...      0
# ...                                                  ...    ...
# 80879  Conservatives are, once again, on the losing s...      0
# 80880  Says Rep. Maxine Waters, D-Calif., only needs ...      0
# 80882  Yolanda Hadid Addresses Gigi Hadid Pregnancy R...      0
# 80883  The Governor did not consult members of his ow...      0
# 80884  WASHINGTON (Reuters) - The U.S. Senate will pu...      1
#
#       original_label              dataset  \
# 0                  1                 ISOT
# 1                  1                 ISOT
# 2          half-true                 LIAR
# 3                  1  FakeNewsNet_Minimal
# 4                  0  FakeNewsNet_Minimal
# ...              ...                  ...
# 80879              0                 ISOT
# 80880      half-true                 LIAR
# 80882              0  FakeNewsNet_Minimal
# 80883          false                 LIAR
# 80884              1                 ISOT
#
#                                               clean_text  \
# 0      reuters president donald trump is set to sign ...
# 1      lany czech republic reuters czech election win...
# 2      says comprehensive immigration reform will add...
# 3      inside nikki bellas strong support system foll...
# 4      ellen degeneres makes joke about jennifer anis...
# ...                                                  ...
# 80879  conservatives are once again on the losing sid...
# 80880  says rep maxine waters dcalif only needs about...
# 80882  yolanda hadid addresses gigi hadid pregnancy r...
# 80883  the governor did not consult members of his ow...
# 80884  washington reuters the us senate will push ahe...
#
#                                                   tokens
# 0      [reuters, president, donald, trump, is, set, t...
# 1      [lany, czech, republic, reuters, czech, electi...
# 2      [says, comprehensive, immigration, reform, wil...
# 3      [inside, nikki, bellas, strong, support, syste...
# 4      [ellen, degeneres, makes, joke, about, jennife...
# ...                                                  ...
# 80879  [conservatives, are, once, again, on, the, los...
# 80880  [says, rep, maxine, waters, dcalif, only, need...
# 80882  [yolanda, hadid, addresses, gigi, hadid, pregn...
# 80883  [the, governor, did, not, consult, members, of...
# 80884  [washington, reuters, the, us, senate, will, p...
#
# [73265 rows x 6 columns]

# %% [markdown]
# ## 5. Remove stopwords

# %%
stop_words = set(stopwords.words('english'))
combined_fake_news_dataset_df['tokens'] = combined_fake_news_dataset_df['tokens'].apply(lambda x: [word for word in x if word not in stop_words])

# %% [markdown]
# ## 6. Lemmatization

# %%
lemmatizer = WordNetLemmatizer()
combined_fake_news_dataset_df['tokens'] = combined_fake_news_dataset_df['tokens'].apply(lambda x: [lemmatizer.lemmatize(word) for word in x])

# %% [markdown]
# ## 7. Rejoin tokens into final processed text

# %%
combined_fake_news_dataset_df['processed_text'] = combined_fake_news_dataset_df['tokens'].apply(lambda x: ' '.join(x))

# %%
combined_fake_news_dataset_df
# Out:
#                                                     text  label  \
# 0      (Reuters) - President Donald Trump is set to s...      1
# 1      LANY, Czech Republic (Reuters) - Czech electio...      1
# 2      Says comprehensive immigration reform will add...      0
# 3      Inside Nikki Bella's Strong Support System Fol...      1
# 4      Ellen DeGeneres makes joke about Jennifer Anis...      0
# ...                                                  ...    ...
# 80879  Conservatives are, once again, on the losing s...      0
# 80880  Says Rep. Maxine Waters, D-Calif., only needs ...      0
# 80882  Yolanda Hadid Addresses Gigi Hadid Pregnancy R...      0
# 80883  The Governor did not consult members of his ow...      0
# 80884  WASHINGTON (Reuters) - The U.S. Senate will pu...      1
#
#       original_label              dataset  \
# 0                  1                 ISOT
# 1                  1                 ISOT
# 2          half-true                 LIAR
# 3                  1  FakeNewsNet_Minimal
# 4                  0  FakeNewsNet_Minimal
# ...              ...                  ...
# 80879              0                 ISOT
# 80880      half-true                 LIAR
# 80882              0  FakeNewsNet_Minimal
# 80883          false                 LIAR
# 80884              1                 ISOT
#
#                                               clean_text  \
# 0      reuters president donald trump is set to sign ...
# 1      lany czech republic reuters czech election win...
# 2      says comprehensive immigration reform will add...
# 3      inside nikki bellas strong support system foll...
# 4      ellen degeneres makes joke about jennifer anis...
# ...                                                  ...
# 80879  conservatives are once again on the losing sid...
# 80880  says rep maxine waters dcalif only needs about...
# 80882  yolanda hadid addresses gigi hadid pregnancy r...
# 80883  the governor did not consult members of his ow...
# 80884  washington reuters the us senate will push ahe...
#
#                                                   tokens  \
# 0      [reuters, president, donald, trump, set, sign,...
# 1      [lany, czech, republic, reuters, czech, electi...
# 2      [say, comprehensive, immigration, reform, add,...
# 3      [inside, nikki, bellas, strong, support, syste...
# 4      [ellen, degeneres, make, joke, jennifer, anist...
# ...                                                  ...
# 80879  [conservative, losing, side, conversation, day...
# 80880  [say, rep, maxine, water, dcalif, need, vote, ...
# 80882  [yolanda, hadid, address, gigi, hadid, pregnan...
# 80883  [governor, consult, member, party, released, p...
# 80884  [washington, reuters, u, senate, push, ahead, ...
#
#                                           processed_text
# 0      reuters president donald trump set sign order ...
# 1      lany czech republic reuters czech election win...
# 2      say comprehensive immigration reform add billi...
# 3      inside nikki bellas strong support system foll...
# 4      ellen degeneres make joke jennifer aniston mar...
# ...                                                  ...
# 80879  conservative losing side conversation day pres...
# 80880  say rep maxine water dcalif need vote win elec...
# 80882   yolanda hadid address gigi hadid pregnancy rumor
# 80883        governor consult member party released plan
# 80884  washington reuters u senate push ahead vote we...
#
# [73265 rows x 7 columns]

# %%
import os
output_dir = "../data/processed"
os.makedirs(output_dir, exist_ok=True)

# Save the file
output_path = os.path.join(output_dir, "cleaned_fake_news_dataset.csv")
combined_fake_news_dataset_df.to_csv(output_path, index=False)
print(f"Cleaned dataset saved to: {output_path}")
# Out:
# Cleaned dataset saved to: ../data/processed\cleaned_fake_news_dataset.csv

# %%
df = pd.read_csv("../data/processed/cleaned_fake_news_dataset.csv")

# %%
df
# Out:
#                                                     text  label  \
# 0      (Reuters) - President Donald Trump is set to s...      1
# 1      LANY, Czech Republic (Reuters) - Czech electio...      1
# 2      Says comprehensive immigration reform will add...      0
# 3      Inside Nikki Bella's Strong Support System Fol...      1
# 4      Ellen DeGeneres makes joke about Jennifer Anis...      0
# ...                                                  ...    ...
# 73260  Conservatives are, once again, on the losing s...      0
# 73261  Says Rep. Maxine Waters, D-Calif., only needs ...      0
# 73262  Yolanda Hadid Addresses Gigi Hadid Pregnancy R...      0
# 73263  The Governor did not consult members of his ow...      0
# 73264  WASHINGTON (Reuters) - The U.S. Senate will pu...      1
#
#       original_label              dataset  \
# 0                  1                 ISOT
# 1                  1                 ISOT
# 2          half-true                 LIAR
# 3                  1  FakeNewsNet_Minimal
# 4                  0  FakeNewsNet_Minimal
# ...              ...                  ...
# 73260              0                 ISOT
# 73261      half-true                 LIAR
# 73262              0  FakeNewsNet_Minimal
# 73263          false                 LIAR
# 73264              1                 ISOT
#
#                                               clean_text  \
# 0      reuters president donald trump is set to sign ...
# 1      lany czech republic reuters czech election win...
# 2      says comprehensive immigration reform will add...
# 3      inside nikki bellas strong support system foll...
# 4      ellen degeneres makes joke about jennifer anis...
# ...                                                  ...
# 73260  conservatives are once again on the losing sid...
# 73261  says rep maxine waters dcalif only needs about...
# 73262  yolanda hadid addresses gigi hadid pregnancy r...
# 73263  the governor did not consult members of his ow...
# 73264  washington reuters the us senate will push ahe...
#
#                                                   tokens  \
# 0      ['reuters', 'president', 'donald', 'trump', 's...
# 1      ['lany', 'czech', 'republic', 'reuters', 'czec...
# 2      ['say', 'comprehensive', 'immigration', 'refor...
# 3      ['inside', 'nikki', 'bellas', 'strong', 'suppo...
# 4      ['ellen', 'degeneres', 'make', 'joke', 'jennif...
# ...                                                  ...
# 73260  ['conservative', 'losing', 'side', 'conversati...
# 73261  ['say', 'rep', 'maxine', 'water', 'dcalif', 'n...
# 73262  ['yolanda', 'hadid', 'address', 'gigi', 'hadid...
# 73263  ['governor', 'consult', 'member', 'party', 're...
# 73264  ['washington', 'reuters', 'u', 'senate', 'push...
#
#                                           processed_text
# 0      reuters president donald trump set sign order ...
# 1      lany czech republic reuters czech election win...
# 2      say comprehensive immigration reform add billi...
# 3      inside nikki bellas strong support system foll...
# 4      ellen degeneres make joke jennifer aniston mar...
# ...                                                  ...
# 73260  conservative losing side conversation day pres...
# 73261  say rep maxine water dcalif need vote win elec...
# 73262   yolanda hadid address gigi hadid pregnancy rumor
# 73263        governor consult member party released plan
# 73264  washington reuters u senate push ahead vote we...
#
# [73265 rows x 7 columns]
